# %%
df = df.drop_duplicates(subset=["logradouro", "tipo_logradouro", "bairro", "cidade", "cep", "tipo"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = df.drop_duplicates(subset=["logradouro", "tipo_logradouro", "bairro", "cidade", "cep", "tipo"])
#
# NameError: name 'df' is not defined
